# %%
try:
    nums = int(input("請輸入一個整數:"))
    if nums % 2 == 0:
        print("偶數")
    else:
        print("奇數")

    if nums == 0:
        print("這是0")
    else:
        if nums > 0:
            print("這是正數")
        else:
            print("這是負數")
except:
    print("格式錯誤")
# Out:
# 格式錯誤
