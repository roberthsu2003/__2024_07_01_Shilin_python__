# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  3.123569  0.066335
# 1    a  two  1.294135  0.115518
# 2    b  one -0.725110 -0.003410
# 3    b  two -0.894326 -0.243430
# 4    a  one -1.197695  0.553389

# %%
df.T
# Out:
#               0         1        2         3         4
# key1          a         a        b         b         a
# key2        one       two      one       two       one
# data1  3.123569  1.294135 -0.72511 -0.894326 -1.197695
# data2  0.066335  0.115518 -0.00341  -0.24343  0.553389

# %%
#因為key1,key2,data1,data2沒有重覆,可以stack()
df.stack()
# Out:
# 0  key1            a
#    key2          one
#    data1    3.123569
#    data2    0.066335
# 1  key1            a
#    key2          two
#    data1    1.294135
#    data2    0.115518
# 2  key1            b
#    key2          one
#    data1    -0.72511
#    data2    -0.00341
# 3  key1            b
#    key2          two
#    data1   -0.894326
#    data2    -0.24343
# 4  key1            a
#    key2          one
#    data1   -1.197695
#    data2    0.553389
# dtype: object

# %%
df1 = df.set_index(['key1','key2'])
df1
# Out:
#               data1     data2
# key1 key2
# a    one   3.123569  0.066335
#      two   1.294135  0.115518
# b    one  -0.725110 -0.003410
#      two  -0.894326 -0.243430
# a    one  -1.197695  0.553389

# %%
#會出錯,因為值有重覆
#df1.unstack(level='key1')
#df1.unstack(level='key2')

# %%
df2 = df.groupby(by=['key1','key2']).max()
df2
# Out:
#               data1     data2
# key1 key2
# a    one   3.123569  0.553389
#      two   1.294135  0.115518
# b    one  -0.725110 -0.003410
#      two  -0.894326 -0.243430

# %%
df2.unstack(level='key2')
# Out:
#          data1               data2
# key2       one       two       one       two
# key1
# a     3.123569  1.294135  0.553389  0.115518
# b    -0.725110 -0.894326 -0.003410 -0.243430

# %%
df2.unstack(level='key1')
# Out:
#          data1               data2
# key1         a         b         a        b
# key2
# one   3.123569 -0.725110  0.553389 -0.00341
# two   1.294135 -0.894326  0.115518 -0.24343
