# %%
import random
with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)
names

# %%
import numpy as np
import pandas as pd
with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df
# Out:
#       國文   英文   數學   地理  歷史
# 謝貞妃   56   79   73   62  60
# 彭茹靖   63   68   74   74  68
# 林詠斌   80   68   71   61  71
# 溫法堯   99   89   68   88  68
# 林群清   92   92  100   64  73
# 朱彥志   92   63   96   78  87
# 白世宏   76   97   91   76  70
# 楊韻如   53   52   72   81  54
# 藍哲嘉   54   97   84   86  94
# 白世宏   89   97   95   80  80
# 黃名明   87   57   58   91  62
# 姜琬婷   80   68  100   69  64
# 黃偉剛   66  100   75   81  78
# 林怡偉   81   89   79   54  59
# 黃彥孝   87   68   85   75  80
# 張明惟   51   81   58   97  52
# 黃政甫   61   90   96   71  57
# 陳孝邦   63   82   61   98  91
# 楊建安   83   54   76   73  67
# 蔡偉成   83   58   57   99  62
# 趙宛真   61   64   68   77  67
# 王柏聖   52   84   58   55  52
# 黃健發   51   50   56   73  53
# 陳建香   99   89   77   83  86
# 鄭佳玲   81   90   91   91  84
# 藍姿婷   83   50   93   68  82
# 陳俊憲   68   82   86   81  88
# 楊建安   74   71   86   67  68
# 林冠蕙   88   94   86   67  86
# 王泓泰   98   79   89   78  50
# 陳怡珊   97   54   73   81  69
# 戚亨    53   75   97   59  50
# 潘俊賢   98   52   57   70  52
# 李政白   94   87   65   96  69
# 景歡燦   54   71   57   72  70
# 方雅慧   76   54   76   83  81
# 張嘉韋  100   69   74   76  72
# 陳向愛   75   59   76   74  88
# 張家秀   85   71   85   89  82
# 賴佳雯   96   50   76   70  75
# 劉嘉泰   92   51   74   96  70
# 黃政甫   75   99   61   78  72
# 彭偉妃   93   97   86   93  99
# 陳凱翔   72   80   83   81  50
# 吳振瑋   72   86   98   91  92
# 潘英迪   94   72   50   58  68
# 吳柏誠   51   69   98   89  74
# 陳筱涵   87   72   98   71  84
# 彭虹屏   84   96   97  100  88
# 沈心利   88   98   91   59  67

# %%
#選取dataframe的一個欄位
display(student_df['國文'])
display(student_df['英文'])

# %%
#選取dataframe的多個欄位
student_df[['國文','英文']]

# %%
sum_series = student_df['國文'] + \
student_df['英文'] + \
student_df['數學'] + \
student_df['地理'] + \
student_df['歷史'] 
mean_series = sum_series / 5
mean_series

# %%
student_df['總分'] = sum_series
student_df['平均'] = mean_series
student_df
# Out:
#       國文   英文   數學   地理  歷史   總分    平均
# 謝貞妃   56   79   73   62  60  330  66.0
# 彭茹靖   63   68   74   74  68  347  69.4
# 林詠斌   80   68   71   61  71  351  70.2
# 溫法堯   99   89   68   88  68  412  82.4
# 林群清   92   92  100   64  73  421  84.2
# 朱彥志   92   63   96   78  87  416  83.2
# 白世宏   76   97   91   76  70  410  82.0
# 楊韻如   53   52   72   81  54  312  62.4
# 藍哲嘉   54   97   84   86  94  415  83.0
# 白世宏   89   97   95   80  80  441  88.2
# 黃名明   87   57   58   91  62  355  71.0
# 姜琬婷   80   68  100   69  64  381  76.2
# 黃偉剛   66  100   75   81  78  400  80.0
# 林怡偉   81   89   79   54  59  362  72.4
# 黃彥孝   87   68   85   75  80  395  79.0
# 張明惟   51   81   58   97  52  339  67.8
# 黃政甫   61   90   96   71  57  375  75.0
# 陳孝邦   63   82   61   98  91  395  79.0
# 楊建安   83   54   76   73  67  353  70.6
# 蔡偉成   83   58   57   99  62  359  71.8
# 趙宛真   61   64   68   77  67  337  67.4
# 王柏聖   52   84   58   55  52  301  60.2
# 黃健發   51   50   56   73  53  283  56.6
# 陳建香   99   89   77   83  86  434  86.8
# 鄭佳玲   81   90   91   91  84  437  87.4
# 藍姿婷   83   50   93   68  82  376  75.2
# 陳俊憲   68   82   86   81  88  405  81.0
# 楊建安   74   71   86   67  68  366  73.2
# 林冠蕙   88   94   86   67  86  421  84.2
# 王泓泰   98   79   89   78  50  394  78.8
# 陳怡珊   97   54   73   81  69  374  74.8
# 戚亨    53   75   97   59  50  334  66.8
# 潘俊賢   98   52   57   70  52  329  65.8
# 李政白   94   87   65   96  69  411  82.2
# 景歡燦   54   71   57   72  70  324  64.8
# 方雅慧   76   54   76   83  81  370  74.0
# 張嘉韋  100   69   74   76  72  391  78.2
# 陳向愛   75   59   76   74  88  372  74.4
# 張家秀   85   71   85   89  82  412  82.4
# 賴佳雯   96   50   76   70  75  367  73.4
# 劉嘉泰   92   51   74   96  70  383  76.6
# 黃政甫   75   99   61   78  72  385  77.0
# 彭偉妃   93   97   86   93  99  468  93.6
# 陳凱翔   72   80   83   81  50  366  73.2
# 吳振瑋   72   86   98   91  92  439  87.8
# 潘英迪   94   72   50   58  68  342  68.4
# 吳柏誠   51   69   98   89  74  381  76.2
# 陳筱涵   87   72   98   71  84  412  82.4
# 彭虹屏   84   96   97  100  88  465  93.0
# 沈心利   88   98   91   59  67  403  80.6
