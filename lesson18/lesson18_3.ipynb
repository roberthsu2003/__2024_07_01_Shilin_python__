# %%
import os
current_path = os.path.dirname(os.path.abspath(__name__))
folder_path = os.path.join(current_path,'每日各站進出站人數')
fileName_list = []
for filename in os.listdir(folder_path):
    if '每日各站進出站人數' in filename:
        fileName_list.append(os.path.join(folder_path,filename))

# %%
import pandas as pd
import json
from pprint import pprint
#車站名稱
stations_path = os.path.join(folder_path,'車站基本資料集.json')
with open(stations_path,encoding='utf-8') as file:
    station_content = json.load(file)

stations_df = pd.DataFrame(station_content)


stations_df['stationCode'] = stations_df['stationCode'].astype(int)
stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stationCode    243 non-null    int64
#  1   stationName    243 non-null    object
#  2   stationEName   243 non-null    object
#  3   name           243 non-null    object
#  4   ename          243 non-null    object
#  5   stationAddrTw  243 non-null    object
#  6   stationAddrEn  243 non-null    object
#  7   stationTel     243 non-null    object
#  8   gps            243 non-null    object
#  9   haveBike       243 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 19.1+ KB

# %%
inOut_df = pd.read_csv(fileName_list[0])
inOut_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86932 entries, 0 to 86931
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   trnOpDate        86932 non-null  int64
#  1   staCode          86932 non-null  int64
#  2   gateInComingCnt  86932 non-null  int64
#  3   gateOutGoingCnt  86932 non-null  int64
# dtypes: int64(4)
# memory usage: 2.7 MB

# %%
df1 = pd.merge(inOut_df,stations_df,left_on='staCode',right_on='stationCode')
df1
# Out:
#        trnOpDate  staCode  gateInComingCnt  gateOutGoingCnt  stationCode  \
# 0       20200101      900             7552             8154          900
# 1       20200101      910             1020             1135          910
# 2       20200101      920             1623             1972          920
# 3       20200101      930             4130             4813          930
# 4       20200101      940             1818             2128          940
# ...          ...      ...              ...              ...          ...
# 86927   20201231     7360             3523             3602         7360
# 86928   20201231     7361                3               18         7361
# 86929   20201231     7362               28               34         7362
# 86930   20201231     7380              609              604         7380
# 86931   20201231     7390              377              444         7390
#
#       stationName stationEName name       ename  \
# 0              基隆      Keelung   基隆     Keelung
# 1              三坑      Sankeng   三坑     Sankeng
# 2              八堵         Badu   八堵        Badu
# 3              七堵         Qidu   七堵        Qidu
# 4              百福        Baifu   百福       Baifu
# ...           ...          ...  ...         ...
# 86927          瑞芳      Ruifang   瑞芳     Ruifang
# 86928         海科館    Haikeguan  海科館   Haikeguan
# 86929         八斗子      Badouzi  八斗子     Badouzi
# 86930         四腳亭   Sijiaoting  四腳亭  Sijiaoting
# 86931          暖暖     Nuannuan   暖暖    Nuannuan
#
#                                        stationAddrTw  \
# 0                                        基隆市仁愛區港西街5號
# 1                                 基隆市仁愛區德厚里龍安街 206 號
# 2                                 基隆市暖暖區八南里八堵路 142 號
# 3                                   基隆市七堵區長興里東新街 2 號
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號
# ...                                              ...
# 86927                            新北市瑞芳區龍潭里明燈路三段 82 號
# 86928                                      基隆市中正區長潭里
# 86929  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 86930                              新北市瑞芳區吉慶里中央路 65 號
# 86931                              基隆市暖暖區暖暖里暖暖街 51 號
#
#                                            stationAddrEn   stationTel  \
# 0      No. 16-1, Zhongshan 1st Rd, Ren`ai Dist., Keel...  02-24263743
# 1       No. 206, Long’an St., Ren`ai Dist., Keelung City  02-24230289
# 2        No. 142, Badu Rd., Nuannuan Dist., Keelung City  02-24560841
# 3           No. 2, Dongxin St., Qidu Dist., Keelung City  02-24553426
# 4      No. 1-1, Mingde 3rd Rd., Qidu Dist., Keelung City  02-24528372
# ...                                                  ...          ...
# 86927  No. 82, Sec. 3, Mingdeng Rd., Ruifang Dist., N...  02-24972033
# 86928      Changtan Vil., Zhongzheng Dist., Keelung City  02-24972033
# 86929  Provincial Highway 2 (Junction of Ruifang Dist...  02-24972033
# 86930  No. 65, Zhongyang Rd., Ruifang Dist., New Taip...  02-24579346
# 86931  No. 66, Nuannuan St., Nuannuan Dist., Keelung ...  02-24972033
#
#                       gps haveBike
# 0      25.13411 121.73997        Y
# 1      25.12305 121.74202        Y
# 2      25.10843 121.72898        Y
# 3      25.09294 121.71415        Y
# 4      25.07795 121.69379        N
# ...                   ...      ...
# 86927  25.10861 121.80596        Y
# 86928  25.13754 121.79997        N
# 86929  25.13545 121.80261        N
# 86930  25.10283 121.76192        N
# 86931  25.10224 121.74048        N
#
# [86932 rows x 14 columns]
