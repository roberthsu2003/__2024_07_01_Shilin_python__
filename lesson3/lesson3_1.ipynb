# %%
name = input("請輸入姓名:")
print(name)
# Out:
# robert

# %%
int('20')
int(float('20.5'))
# Out:
# 20

# %%
float('20.5')
# Out:
# 20.5

# %%
eval("3 + 5")
# Out:
# 8

# %%
eval("3.5 + 5")
# Out:
# 8.5

# %%
eval("3.5")
# Out:
# 3.5

# %%
eval('3')
# Out:
# 3

# %%
int(input("請輸入整數:"))
# Out:
# 45

# %%
float(input("請輸入浮點數:"))
# Out:
# 34.0

# %%
eval(input("請輸入整數或浮點數"))
# Out:
# 14.5
