# %%
import matplotlib.pyplot as plt
labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
fig, ax = plt.subplots()
ax.pie(values,
        labels=labels,
        autopct='%1.2f%%',
        colors=['yellow', 'green', 'red', 'blue'],
        explode=[0.3,0,0,0],
        shadow=True,
        startangle=180)
plt.show()
