# %%
import requests
from requests import Response
from pprint import pprint
from requests import ConnectionError,TooManyRedirects,Timeout,HTTPError

youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
try:
    response:Response = requests.get(youbike_url)
    response.raise_for_status()
except ConnectionError:
    print("連線主機出問題")
except TooManyRedirects:
    print("太多轉址")
except Timeout:
    print("主機正在忙")
except HTTPError:
    print("status_不是200")
except:
    print("不明錯誤")
else:
    print("連線正常")
# Out:
# 連線正常

# %%
data:list[dict] = response.json()
sareas:list[str] = []
for site in data:
    sareas.append(site['sarea'])
sareas

# %%
data:list[dict] = response.json()
sareas:set = set()
for site in data:
    sareas.add(site['sarea'])
list(sareas)
# Out:
# ['瑞芳區',
#  '汐止區',
#  '石碇區',
#  '土城區',
#  '三重區',
#  '五股區',
#  '泰山區',
#  '八里區',
#  '板橋區',
#  '三峽區',
#  '石門區',
#  '新店區',
#  '三芝區',
#  '中和區',
#  '萬里區',
#  '永和區',
#  '淡水區',
#  '深坑區',
#  '林口區',
#  '坪林區',
#  '金山區']

# %%
data:list[dict] = response.json()
    
district:str = input("請輸入新北市行政區: ")
district += "區"

district_stations = []
for station in data:
    if station['sarea'] == district:
        district_stations.append(station)


if district_stations:
    pprint(district_stations)
else:
    print(f"沒有找到 {district} 行政區的站點資訊。請再輸入一次")
# Out:
# [{'act': '1',
#   'ar': '仁愛路352巷96號(對面廣場)',
#   'aren': 'No.96, Ln. 352, Ren’ai Rd.',
#   'bemp': '35',
#   'lat': '25.00785',
#   'lng': '121.50099',
#   'mday': '20240729135121',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_名利橋',
#   'snaen': 'YouBike2.0_Minli Bridge',
#   'sno': '500210001',
#   'tot': '39'},
#  {'act': '1',
#   'ar': '保順路53號(對面)',
#   'aren': 'No. 53, Baoshun Rd.',
#   'bemp': '59',
#   'lat': '25.01135',
#   'lng': '121.50285',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '10',
#   'sna': 'YouBike2.0_保順環河西路口',
#   'snaen': 'YouBike2.0_Baoshun & Huanhe W. Intersection',
#   'sno': '500210002',
#   'tot': '69'},
#  {'act': '1',
#   'ar': '永平路/永平路203巷口(靠學校圍牆路側)',
#   'aren': 'Yongping Rd./Ln. 203, Yongping Rd.',
#   'bemp': '22',
#   'lat': '25.00979',
#   'lng': '121.50909',
#   'mday': '20240729134719',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '17',
#   'sna': 'YouBike2.0_永平高中',
#   'snaen': 'YouBike2.0_Yong-Ping High School',
#   'sno': '500210003',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '仁愛路287號(對面)',
#   'aren': 'No. 287, Renai Rd.',
#   'bemp': '52',
#   'lat': '25.00952',
#   'lng': '121.50542',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '27',
#   'sna': 'YouBike2.0_仁愛公園',
#   'snaen': 'YouBike2.0_Renai Park',
#   'sno': '500210004',
#   'tot': '79'},
#  {'act': '1',
#   'ar': '中正路426號(對面)',
#   'aren': 'No.426, Zhongzheng Rd. (Oppsite)',
#   'bemp': '35',
#   'lat': '25.00227',
#   'lng': '121.51744',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_永和國小',
#   'snaen': 'YouBike2.0_Yonghe Elementary School',
#   'sno': '500210005',
#   'tot': '37'},
#  {'act': '1',
#   'ar': '民生路23號(對面)',
#   'aren': 'No.23, Minsheng Rd. (Oppsite)',
#   'bemp': '28',
#   'lat': '24.99896',
#   'lng': '121.52278',
#   'mday': '20240729135319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '20',
#   'sna': 'YouBike2.0_秀朗國小',
#   'snaen': 'YouBike2.0_Xiu Lang Elementary School',
#   'sno': '500210006',
#   'tot': '48'},
#  {'act': '1',
#   'ar': '永利路131號(對面人行道)',
#   'aren': 'No.131, Yongli Rd. (Oppsite)',
#   'bemp': '29',
#   'lat': '25.00317',
#   'lng': '121.52407',
#   'mday': '20240729135218',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '24',
#   'sna': 'YouBike2.0_永和國民運動中心',
#   'snaen': 'YouBike2.0_Yonghe Civil Sports Center',
#   'sno': '500210007',
#   'tot': '53'},
#  {'act': '1',
#   'ar': '永亨路99號(對向人行道)',
#   'aren': 'No.99, Yongheng Rd. (Oppsite)',
#   'bemp': '47',
#   'lat': '25.00501',
#   'lng': '121.52267',
#   'mday': '20240729135414',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_福和國中停車場',
#   'snaen': 'YouBike2.0_Fuhe Junior High School Parking Lot',
#   'sno': '500210008',
#   'tot': '48'},
#  {'act': '1',
#   'ar': '永貞路/永亨路(東南側)',
#   'aren': 'Yongzhen Rd. / Yongheng Rd. Intersection',
#   'bemp': '60',
#   'lat': '25.00595',
#   'lng': '121.52093',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_福和國中',
#   'snaen': 'YouBike2.0_Fuhe Junior High School',
#   'sno': '500210009',
#   'tot': '63'},
#  {'act': '1',
#   'ar': '保安路260號(對面)',
#   'aren': "No.260, Bao'an Rd. (opposite)",
#   'bemp': '37',
#   'lat': '25.01233',
#   'lng': '121.50604',
#   'mday': '20240729135031',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_保安永平路口',
#   'snaen': 'YouBike2.0_Bao’an & Yongping Intersection',
#   'sno': '500210010',
#   'tot': '47'},
#  {'act': '1',
#   'ar': '文化路133號(西側)',
#   'aren': 'No.133, Wenhua Rd.',
#   'bemp': '40',
#   'lat': '25.01581',
#   'lng': '121.51126',
#   'mday': '20240729133620',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_頂溪國小',
#   'snaen': 'YouBike2.0_Tinghsi Elementary School',
#   'sno': '500210011',
#   'tot': '44'},
#  {'act': '1',
#   'ar': '永和區保平路214巷12弄12號(對面路側)',
#   'aren': 'No.12, Aly. 12, Ln. 214, Baoping Rd., Yonghe Dist.',
#   'bemp': '23',
#   'lat': '25.00701',
#   'lng': '121.50921',
#   'mday': '20240729135121',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_保平路214巷',
#   'snaen': 'YouBike2.0_Baoping Ln 214',
#   'sno': '500210012',
#   'tot': '25'},
#  {'act': '1',
#   'ar': '環河西路一段/環河西路一段95巷(人行道)',
#   'aren': 'Sec. 1, Huanhe W. Rd. / Ln. 95, Sec. 1, Huanhe W. Rd., Yonghe Dist.',
#   'bemp': '33',
#   'lat': '25.01783',
#   'lng': '121.51196',
#   'mday': '20240729135219',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_環河西路一段95巷口',
#   'snaen': 'YouBike2.0_Ln. 95, Sec. 1, Huanhe W. Rd.Intersection',
#   'sno': '500210013',
#   'tot': '35'},
#  {'act': '1',
#   'ar': '忠孝街26巷8號(前)',
#   'aren': 'No.8, Ln. 26, Zhongxiao St., Yonghe Dist.',
#   'bemp': '21',
#   'lat': '25.01677',
#   'lng': '121.51528',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_忠孝活動中心',
#   'snaen': 'YouBike2.0_Zhongxiao Activity Center',
#   'sno': '500210014',
#   'tot': '28'},
#  {'act': '1',
#   'ar': '成功路二段28號至34號',
#   'aren': 'No.28 to No.34, Sec. 2, Chenggong Rd.',
#   'bemp': '12',
#   'lat': '25.00071',
#   'lng': '121.52673',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '16',
#   'sna': 'YouBike2.0_秀得里(成功路二段)',
#   'snaen': 'YouBike2.0_Xiu de Village (Chenggong Rd. Sec. 2)',
#   'sno': '500210015',
#   'tot': '28'},
#  {'act': '1',
#   'ar': '永和區國光路9號(前人行道)',
#   'aren': 'No.9, Guoguang Rd., Yonghe Dist.',
#   'bemp': '25',
#   'lat': '25.00839',
#   'lng': '121.52023',
#   'mday': '20240729135218',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_永和國父紀念館',
#   'snaen': 'YouBike2.0_Yonghe-Sun Yat-Sen Memorial Hall',
#   'sno': '500210016',
#   'tot': '32'},
#  {'act': '1',
#   'ar': '永和區 自由街69號(路側)',
#   'aren': 'Ziyou St., Yonghe Dist.(oppsite)',
#   'bemp': '31',
#   'lat': '25.0052',
#   'lng': '121.51334',
#   'mday': '20240729134714',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_永和自由街',
#   'snaen': 'YouBike2.0_Yonghe Ziyou St.',
#   'sno': '500210017',
#   'tot': '32'},
#  {'act': '1',
#   'ar': '民權路60號(活動中心後方廣場)',
#   'aren': 'No. 60, Minquan Rd., Yonghe Dist.',
#   'bemp': '27',
#   'lat': '24.99778',
#   'lng': '121.51968',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_民權社區活動中心',
#   'snaen': 'YouBike2.0_Minquan Community Activity Center',
#   'sno': '500210018',
#   'tot': '35'},
#  {'act': '1',
#   'ar': '環河東路一段/光復街口',
#   'aren': 'Sec. 1, Huanhe E. Rd./Guangfu St.',
#   'bemp': '24',
#   'lat': '25.01776',
#   'lng': '121.51681',
#   'mday': '20240729134319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '16',
#   'sna': 'YouBike2.0_中正橋',
#   'snaen': 'YouBike2.0_Zhongzheng Bridge',
#   'sno': '500210019',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '環河東路一段140號',
#   'aren': 'Sec. 1, Huanhe E. Rd./Aly. 25, Ln. 75, Zhulin Rd.',
#   'bemp': '37',
#   'lat': '25.015',
#   'lng': '121.52095',
#   'mday': '20240729135031',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '5',
#   'sna': 'YouBike2.0_上林里(環河東路一段)',
#   'snaen': 'YouBike2.0_Shanglin Village (Huanhe E. Rd. Sec. 1 )',
#   'sno': '500210020',
#   'tot': '42'},
#  {'act': '1',
#   'ar': '福和路11號',
#   'aren': 'No.11, Fuhe Rd., Yonghe Dist.',
#   'bemp': '33',
#   'lat': '25.00854',
#   'lng': '121.52473',
#   'mday': '20240729135214',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_福和路7巷口',
#   'snaen': 'YouBike2.0_Ln. 7, Fuhe Rd.',
#   'sno': '500210021',
#   'tot': '35'},
#  {'act': '1',
#   'ar': '環河東路三段90號',
#   'aren': 'No.90, Sec. 3, Huanhe E. Rd., Yonghe Dist.',
#   'bemp': '22',
#   'lat': '25.00454',
#   'lng': '121.52785',
#   'mday': '20240729131918',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '19',
#   'sna': 'YouBike2.0_福和橋',
#   'snaen': 'YouBike2.0_Fuhe Bridge',
#   'sno': '500210022',
#   'tot': '41'},
#  {'act': '1',
#   'ar': '中山路二段3巷2號(對面公園)',
#   'aren': 'No.2, Ln. 3, Sec. 2, Zhongshan Rd.(Opposite)',
#   'bemp': '31',
#   'lat': '25.00573',
#   'lng': '121.50574',
#   'mday': '20240729133720',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_雙和橋',
#   'snaen': 'YouBike2.0_Shuanghe Bridge',
#   'sno': '500210023',
#   'tot': '39'},
#  {'act': '1',
#   'ar': '永和路二段',
#   'aren': 'Sec. 2, Yonghe Rd. & Ln. 231, Sec. 2, Yonghe Rd. (Southwest)',
#   'bemp': '8',
#   'lat': '25.01424',
#   'lng': '121.51549',
#   'mday': '20240729135414',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_捷運頂溪站(2號出口)',
#   'snaen': 'YouBike2.0_MRT Ding Sta(exit 2)',
#   'sno': '500210024',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '國光路123號 ( 耕莘醫院外路側汽機車格位 )',
#   'aren': 'No.123, Guoguang Rd.',
#   'bemp': '29',
#   'lat': '25.01123',
#   'lng': '121.5177',
#   'mday': '20240729135219',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_永和耕莘醫院',
#   'snaen': 'YouBike2.0_Yonghe Cardinal Tien Hospital',
#   'sno': '500210025',
#   'tot': '32'},
#  {'act': '1',
#   'ar': '環河東路四段/民樂街59巷26弄口(西北側)',
#   'aren': 'Section 4, Huanhe East Rd. Alley 26, Lane 59, Minyue St. '
#           '(Northwest)',
#   'bemp': '12',
#   'lat': '24.99798',
#   'lng': '121.52844',
#   'mday': '20240729133420',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_環河民樂街59巷26弄口',
#   'snaen': 'YouBike2.0_Huanh Alley 26, Lane 59, Minyue St.',
#   'sno': '500210026',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '永平路274號(對面)',
#   'aren': 'No. 274, Yongping Rd.(Front)',
#   'bemp': '15',
#   'lat': '25.01138',
#   'lng': '121.50796',
#   'mday': '20240729135418',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_仁愛公園(仁愛路)',
#   'snaen': 'YouBike2.0_Ren Ai Park (Ren Ai Rd.)',
#   'sno': '500210027',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '豫溪街217巷29號',
#   'aren': 'No.29, Ln. 217, Yuxi St.',
#   'bemp': '52',
#   'lat': '25.01003',
#   'lng': '121.52418',
#   'mday': '20240729135418',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_永福橋',
#   'snaen': 'YouBike2.0_Yongfu Bridge',
#   'sno': '500210028',
#   'tot': '55'},
#  {'act': '1',
#   'ar': '永和路一段85號前(北側)',
#   'aren': 'No. 85, Sec 1, Yonghe Rd.(North)',
#   'bemp': '12',
#   'lat': '25.00746',
#   'lng': '121.5134',
#   'mday': '20240729133521',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_保平永和路一段口',
#   'snaen': 'YouBike2.0_Baoping Sec 1, Yonghe Rd.Intersection',
#   'sno': '500210029',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '福和路320號(前)',
#   'aren': 'No. 320, Fuhe Rd.',
#   'bemp': '11',
#   'lat': '25.00725',
#   'lng': '121.51572',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_福和自強街28巷口',
#   'snaen': 'YouBike2.0_Fuhe & Ln. 28, Ziqiang St. Intersection',
#   'sno': '500210030',
#   'tot': '19'},
#  {'act': '1',
#   'ar': '國中路156號(對面)',
#   'aren': 'No. 156, Guozhong Rd.',
#   'bemp': '12',
#   'lat': '25.00674',
#   'lng': '121.52269',
#   'mday': '20240729135031',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_永和國中(國中路)',
#   'snaen': 'YouBike2.0_Yonghe Junior High School(Guozhong Rd.)',
#   'sno': '500210031',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '國光路12巷/中正路666巷(東北側)',
#   'aren': 'Ln. 12, Guoguang Rd. & Ln. 666, Zhongzheng Rd(Northeast)',
#   'bemp': '10',
#   'lat': '25.00913',
#   'lng': '121.51917',
#   'mday': '20240729133515',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_中正路666巷口',
#   'snaen': 'YouBike2.0_Ln. 666, Zhongzheng Rd.',
#   'sno': '500210032',
#   'tot': '10'},
#  {'act': '1',
#   'ar': '永貞路312號(前)',
#   'aren': 'No. 312, Yongzhen Rd.',
#   'bemp': '7',
#   'lat': '25.00492',
#   'lng': '121.5117',
#   'mday': '20240729135031',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '5',
#   'sna': 'YouBike2.0_永貞水源街口',
#   'snaen': 'YouBike2.0_Yongzheng Shuiyuan St. Intersection',
#   'sno': '500210033',
#   'tot': '12'},
#  {'act': '0',
#   'ar': '新生路193巷1號(前)',
#   'aren': 'No. 1, Ln. 193, Xinsheng Rd.',
#   'bemp': '12',
#   'lat': '25.01402',
#   'lng': '121.50704',
#   'mday': '20240726031918',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_永和區公所公有新生市場',
#   'snaen': 'YouBike2.0_Yonghe Xinsheng Market',
#   'sno': '500210034',
#   'tot': '12'},
#  {'act': '1',
#   'ar': '保安路75號(前)',
#   'aren': "No. 75, Bao'an Rd.",
#   'bemp': '13',
#   'lat': '25.01497',
#   'lng': '121.5087',
#   'mday': '20240729134814',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_保安保福路二段口',
#   'snaen': "YouBike2.0_Bao'an & Sec. 2, Bao'fu Rd. Intersection",
#   'sno': '500210035',
#   'tot': '14'},
#  {'act': '1',
#   'ar': '保福路二段128號(前)',
#   'aren': "No. 128, Sec. 2, Bao'fu Rd.",
#   'bemp': '11',
#   'lat': '25.01422',
#   'lng': '121.5097',
#   'mday': '20240729134718',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_保福保福路二段133巷口',
#   'snaen': "YouBike2.0_Bao'fu & Ln. 133, Sec. 2, Bao'fu Rd. Intersection",
#   'sno': '500210036',
#   'tot': '14'},
#  {'act': '1',
#   'ar': '仁愛路97號(前)',
#   'aren': "No. 97, Ren'ai Rd.",
#   'bemp': '12',
#   'lat': '25.01329',
#   'lng': '121.51269',
#   'mday': '20240729135319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_仁愛信義路口',
#   'snaen': "YouBike2.0_Ren'ai Xinyi Rd. Intersection",
#   'sno': '500210037',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '永和路二段242號(旁人行道)',
#   'aren': 'No. 242, Sec. 2, Yonghe Rd.',
#   'bemp': '5',
#   'lat': '25.01455',
#   'lng': '121.51583',
#   'mday': '20240729134520',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '5',
#   'sna': 'YouBike2.0_永和勵行街口',
#   'snaen': 'YouBike2.0_Yonghe Lixing St. Intersection',
#   'sno': '500210038',
#   'tot': '10'},
#  {'act': '1',
#   'ar': '仁愛路306巷18弄3號',
#   'aren': "No. 3, Aly. 18, Ln. 306, Ren'ai Rd.",
#   'bemp': '9',
#   'lat': '25.00888',
#   'lng': '121.50303',
#   'mday': '20240729135219',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_仁愛路306巷18弄口',
#   'snaen': "YouBike2.0_Aly. 18, Ln. 306, Ren'ai Rd. Intersection",
#   'sno': '500210039',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '環河西路二段249號',
#   'aren': 'No. 249, Sec. 2, Huanhe W. Rd.',
#   'bemp': '3',
#   'lat': '25.009',
#   'lng': '121.49972',
#   'mday': '20240729134319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_瓦磘截流站',
#   'snaen': 'YouBike2.0_Wayao Interception & Pumping Plant',
#   'sno': '500210040',
#   'tot': '11'},
#  {'act': '1',
#   'ar': '環河西路二段5號',
#   'aren': 'No. 5, Sec. 2, Huanhe W. Rd.',
#   'bemp': '12',
#   'lat': '25.0173',
#   'lng': '121.5101',
#   'mday': '20240729135319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_永成市民活動中心',
#   'snaen': 'YouBike2.0_Yongzheng Civic Activity Center',
#   'sno': '500210041',
#   'tot': '12'},
#  {'act': '1',
#   'ar': '秀朗路二段24巷16弄24號',
#   'aren': 'No. 24, Aly. 16, Ln. 24, Sec. 2, Xiulang Rd.',
#   'bemp': '10',
#   'lat': '25.00239',
#   'lng': '121.52007',
#   'mday': '20240729133216',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_秀朗路二段24巷16弄24號',
#   'snaen': 'YouBike2.0_No. 24, Aly. 16, Ln. 24, Sec. 2, Xiulang Rd.',
#   'sno': '500210042',
#   'tot': '14'},
#  {'act': '1',
#   'ar': '環河西路一段/永和路二段425巷(東南側)',
#   'aren': 'Sec. 1, Huanhe W. Rd. & Ln. 425, Sec. 2, Yonghe Rd.(Southeast)',
#   'bemp': '15',
#   'lat': '25.01803',
#   'lng': '121.51553',
#   'mday': '20240729131919',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_中正橋(環河西路一段)',
#   'snaen': 'YouBike2.0_Zhongzheng Birdge(Sec. 1, Huanhe W. Rd.)',
#   'sno': '500210043',
#   'tot': '24'},
#  {'act': '1',
#   'ar': '仁愛路46號(前)',
#   'aren': "No. 46, Ren'ai Rd.",
#   'bemp': '7',
#   'lat': '25.01346',
#   'lng': '121.51416',
#   'mday': '20240729135414',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_仁愛路40巷口',
#   'snaen': "YouBike2.0_Ln. 40, Ren'ai Rd. Intersection",
#   'sno': '500210044',
#   'tot': '14'},
#  {'act': '1',
#   'ar': '永和路二段168號(旁)',
#   'aren': 'No. 168, Sec. 2, Yonghe Rd.',
#   'bemp': '5',
#   'lat': '25.0131',
#   'lng': '121.51544',
#   'mday': '20240729135319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '10',
#   'sna': 'YouBike2.0_捷運頂溪站(復興街1巷)',
#   'snaen': 'YouBike2.0_MRT Dingxi Sta.(Ln. 1, Fuxing St.)',
#   'sno': '500210045',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '中興街1號(前)',
#   'aren': 'No. 1, Zhongxing St.',
#   'bemp': '10',
#   'lat': '25.01223',
#   'lng': '121.51526',
#   'mday': '20240729135419',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_捷運頂溪站(中興街)',
#   'snaen': 'YouBike2.0_MRT Dingxi Sta.(Zhongxing St.)',
#   'sno': '500210046',
#   'tot': '48'},
#  {'act': '1',
#   'ar': '文化路135巷64號(旁)',
#   'aren': 'No. 64, Ln. 135, Wenhua Rd.',
#   'bemp': '13',
#   'lat': '25.01452',
#   'lng': '121.51057',
#   'mday': '20240729135314',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_頂溪國小地下停車場',
#   'snaen': 'YouBike2.0_Dingxi Elementary School Parking',
#   'sno': '500210047',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '中山路一段19號(旁)',
#   'aren': 'No. 19, Sec. 1, Zhongshan Rd.',
#   'bemp': '0',
#   'lat': '25.01039',
#   'lng': '121.51375',
#   'mday': '20240729134614',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '11',
#   'sna': 'YouBike2.0_中山路一段17巷口',
#   'snaen': 'YouBike2.0_Ln. 17, Sec. 1, Zhongshan Rd.Intersection',
#   'sno': '500210048',
#   'tot': '11'},
#  {'act': '1',
#   'ar': '中興街88號',
#   'aren': 'No. 88, Zhongxing St.',
#   'bemp': '10',
#   'lat': '25.01228',
#   'lng': '121.51864',
#   'mday': '20240729134820',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_中信停車場(中興街)',
#   'snaen': 'YouBike2.0_Zhongxin Parking Lot(Zhongxing St.)',
#   'sno': '500210049',
#   'tot': '17'},
#  {'act': '1',
#   'ar': '雙和街37巷4號(旁)',
#   'aren': 'No.4, Ln.37, Shuanghe St. (Side)',
#   'bemp': '1',
#   'lat': '25.00229',
#   'lng': '121.50883',
#   'mday': '20240729135031',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_雙和公園',
#   'snaen': 'YouBike2.0_Shuanghe Park',
#   'sno': '500210050',
#   'tot': '11'},
#  {'act': '1',
#   'ar': '中正路465巷36號(前)',
#   'aren': 'No.36, Ln.465, Zhongzheng Rd. (front)',
#   'bemp': '13',
#   'lat': '25.00587',
#   'lng': '121.51591',
#   'mday': '20240729135031',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_中正路465巷',
#   'snaen': 'YouBike2.0_Ln.465, Zhongzheng Rd.',
#   'sno': '500210051',
#   'tot': '17'},
#  {'act': '1',
#   'ar': '環河西路二段221號(前)',
#   'aren': 'No. 221, Sec. 2, Huanhe W. Rd. (Front)',
#   'bemp': '13',
#   'lat': '25.01016',
#   'lng': '121.50109',
#   'mday': '20240729135418',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_環河西路二段217巷口',
#   'snaen': 'YouBike2.0_Ln. 217, Sec. 2, Huanhe W. Rd. Intersection',
#   'sno': '500210052',
#   'tot': '17'},
#  {'act': '1',
#   'ar': '保平路236巷1弄15號(旁)',
#   'aren': 'No. 15, Aly. 1, Ln. 236, Baoping Rd. (Side)',
#   'bemp': '10',
#   'lat': '25.00532',
#   'lng': '121.50857',
#   'mday': '20240729134319',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_保平路268巷',
#   'snaen': 'YouBike2.0_Ln. 268, Baoping Rd.',
#   'sno': '500210053',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '中正路238號(前)',
#   'aren': 'No. 238, Zhongzheng Rd. (Front)',
#   'bemp': '5',
#   'lat': '24.99816',
#   'lng': '121.51634',
#   'mday': '20240729132520',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_中正路242巷口',
#   'snaen': 'YouBike2.0_Ln. 242, Zhongzheng Rd. Intersection',
#   'sno': '500210054',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '永利路72號(對面)',
#   'aren': 'No. 72, YongLi Rd. (Opposite)',
#   'bemp': '21',
#   'lat': '25.00432',
#   'lng': '121.52033',
#   'mday': '20240729135026',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_福和國中(永利路)',
#   'snaen': 'YouBike2.0_Fuhe Junior High School (YongLi Rd.)',
#   'sno': '500210055',
#   'tot': '22'}]
