# %%
import numpy as np

np.linspace(1,50,num=500)

# %%
scores = np.random.randint(50,101,size=(50,5))
scores
# Out:
# array([[ 51,  63,  52,  78,  63],
#        [100,  58,  76,  92,  79],
#        [ 75,  72,  52,  95,  77],
#        [ 63,  63,  60,  66,  55],
#        [ 64,  83,  76,  70,  61],
#        [ 91,  74, 100,  83,  62],
#        [ 74,  89,  98,  63,  96],
#        [ 65, 100,  84,  60,  61],
#        [ 68,  73,  70,  95,  73],
#        [ 56, 100,  68,  70,  51],
#        [ 64,  63,  73,  99,  57],
#        [ 79,  71,  84,  60,  75],
#        [ 80,  91,  65,  70,  59],
#        [ 84,  76,  52,  55,  72],
#        [ 80,  64,  70,  70,  76],
#        [ 59,  59,  99,  69,  67],
#        [ 88,  88,  91,  92,  56],
#        [ 75,  78,  98,  90,  77],
#        [ 63,  77,  82,  76,  66],
#        [ 93,  89,  99,  51,  66],
#        [ 56,  72,  75,  60,  83],
#        [ 66,  95,  65,  73,  64],
#        [ 71,  65,  70,  89,  84],
#        [ 93,  82,  71,  53,  67],
#        [ 59,  69,  91,  76,  77],
#        [ 95,  71,  62,  61,  68],
#        [ 82,  69,  72,  93,  72],
# ...
