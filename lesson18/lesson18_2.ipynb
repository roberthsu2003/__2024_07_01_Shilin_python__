# %%
import random
import numpy as np
import pandas as pd

with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)

with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df

# %%
from pandas import Series,DataFrame
def fun3(s:Series):
    sum = s.sum()
    mean = s.mean()
    count = s[s<60].count()
    values = s[s<60].index.values
    return Series([sum,mean,count,values],index=['總分','平均','不及格數','不及格科目'])

student_df.apply(fun3,axis=1)
# Out:
#       總分    平均  不及格數         不及格科目
# 李進慧  423  84.6     0            []
# 黃善迪  378  75.6     1          [英文]
# 蘇婷婷  434  86.8     0            []
# 馮芳如  371  74.2     1          [數學]
# 周怡啟  405  81.0     0            []
# 王泓泰  391  78.2     0            []
# 黃佩芬  406  81.2     1          [英文]
# 張家秀  423  84.6     0            []
# 陳冠竹  370  74.0     2      [國文, 歷史]
# 張明惟  381  76.2     1          [英文]
# 陳向愛  402  80.4     0            []
# 余宗儒  335  67.0     2      [數學, 歷史]
# 戚亨   329  65.8     2      [國文, 地理]
# 李雅怡  405  81.0     0            []
# 吳振瑋  338  67.6     0            []
# 黃善迪  377  75.4     0            []
# 吳淑惠  428  85.6     0            []
# 謝南慧  303  60.6     2      [英文, 地理]
# 王孝純  410  82.0     0            []
# 王雅琴  295  59.0     3  [數學, 地理, 歷史]
# 張牧聿  372  74.4     1          [地理]
# 陳姵彬  407  81.4     0            []
# 潘英迪  344  68.8     0            []
# 李政成  382  76.4     1          [數學]
# 沈心利  312  62.4     3  [國文, 數學, 歷史]
# 陳淑娟  352  70.4     3  [國文, 數學, 地理]
# 黃江旭  370  74.0     1          [地理]
# 劉萬季  378  75.6     1          [數學]
# 朱士弘  318  63.6     3  [國文, 數學, 地理]
# 劉耿琦  399  79.8     1          [數學]
# 鄧亭聿  388  77.6     1          [國文]
# 林義皓  410  82.0     0            []
# 陳奇瑄  412  82.4     1          [地理]
# 高俊男  347  69.4     2      [數學, 地理]
# 白世宏  416  83.2     0            []
# 彭偉妃  387  77.4     1          [歷史]
# 林佳光  366  73.2     1          [地理]
# 郭坤花  358  71.6     1          [國文]
# 鄭孟芳  331  66.2     2      [國文, 英文]
# 王雅琴  343  68.6     1          [英文]
# 郭致恬  405  81.0     0            []
# 楊少亮  327  65.4     3  [數學, 地理, 歷史]
# 陳淑娟  395  79.0     0            []
# 劉耿琦  368  73.6     1          [國文]
# 高信宏  420  84.0     0            []
# 黃旻林  333  66.6     2      [國文, 英文]
# 馬彥文  375  75.0     1          [英文]
# 龐皓芳  367  73.4     2      [國文, 地理]
# 林佳人  343  68.6     1          [地理]
# 游一鈺  327  65.4     2      [數學, 歷史]
