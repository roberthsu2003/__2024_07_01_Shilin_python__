# %%
from os.path import abspath,dirname,join

file_path:str = join(dirname(abspath(__name__)),'data','peoples.csv')
file_path
# Out:
# '/workspaces/__2024_07_01_Shilin_python__/lesson12/data/peoples.csv'

# %%
from csv import DictReader
from pprint import pprint

with open(file_path,encoding='utf-8',newline='') as file:
    reader = DictReader(file)
    pprint(list(reader))
# Out:
# [{'BMI': '24.54', '姓名': '王雅慧', '狀態': '體重過重', '身高': '185', '體重': '84'},
#  {'BMI': '22.19', '姓名': '黃佩玲', '狀態': '體重正常', '身高': '156', '體重': '54'},
#  {'BMI': '26.33', '姓名': '王雅慧', '狀態': '體重過重', '身高': '171', '體重': '77'},
#  {'BMI': '16.87', '姓名': '王明昇', '狀態': '體重過輕', '身高': '187', '體重': '59'},
#  {'BMI': '36.05', '姓名': '鄧亭聿', '狀態': '重度肥胖', '身高': '158', '體重': '90'},
#  {'BMI': '24.65', '姓名': '張天亨', '狀態': '體重過重', '身高': '190', '體重': '89'},
#  {'BMI': '23.63', '姓名': '黃心航', '狀態': '體重正常', '身高': '158', '體重': '59'},
#  {'BMI': '34.21', '姓名': '周芷蓁', '狀態': '中度肥胖', '身高': '151', '體重': '78'},
#  {'BMI': '33.09', '姓名': '臧怡君', '狀態': '中度肥胖', '身高': '164', '體重': '89'},
#  {'BMI': '16.6', '姓名': '楊又源', '狀態': '體重過輕', '身高': '177', '體重': '52'},
#  {'BMI': '30.11', '姓名': '王德城', '狀態': '中度肥胖', '身高': '163', '體重': '80'},
#  {'BMI': '28.09', '姓名': '吳志宣', '狀態': '輕度肥胖', '身高': '178', '體重': '89'},
#  {'BMI': '16.01', '姓名': '唐翊修', '狀態': '體重過輕', '身高': '187', '體重': '56'},
#  {'BMI': '22.04', '姓名': '聶心怡', '狀態': '體重正常', '身高': '182', '體重': '73'},
#  {'BMI': '36.16', '姓名': '聶心怡', '狀態': '重度肥胖', '身高': '156', '體重': '88'},
#  {'BMI': '37.33', '姓名': '高智超', '狀態': '重度肥胖', '身高': '150', '體重': '84'},
#  {'BMI': '20.6', '姓名': '蔡明平', '狀態': '體重正常', '身高': '183', '體重': '69'},
#  {'BMI': '35.88', '姓名': '簡美君', '狀態': '重度肥胖', '身高': '153', '體重': '84'},
#  {'BMI': '19.49', '姓名': '吳晴洋', '狀態': '體重正常', '身高': '184', '體重': '66'},
#  {'BMI': '19.16', '姓名': '游詩亞', '狀態': '體重正常', '身高': '174', '體重': '58'},
#  {'BMI': '17.92', '姓名': '白世宏', '狀態': '體重過輕', '身高': '189', '體重': '64'},
#  {'BMI': '22.74', '姓名': '李雅怡', '狀態': '體重正常', '身高': '184', '體重': '77'},
#  {'BMI': '17.34', '姓名': '林怡偉', '狀態': '體重過輕', '身高': '186', '體重': '60'},
#  {'BMI': '22.6', '姓名': '陳信宏', '狀態': '體重正常', '身高': '176', '體重': '70'},
#  {'BMI': '27.48', '姓名': '林冠蕙', '狀態': '輕度肥胖', '身高': '163', '體重': '73'},
#  {'BMI': '28.4', '姓名': '方雅慧', '狀態': '輕度肥胖', '身高': '157', '體重': '70'},
#  {'BMI': '20.9', '姓名': '陳得映', '狀態': '體重正常', '身高': '175', '體重': '64'},
#  {'BMI': '29.59', '姓名': '王雅慧', '狀態': '輕度肥胖', '身高': '156', '體重': '72'},
#  {'BMI': '31.22', '姓名': '吳振瑋', '狀態': '中度肥胖', '身高': '165', '體重': '85'},
#  {'BMI': '21.05', '姓名': '陳凱翔', '狀態': '體重正常', '身高': '190', '體重': '76'},
#  {'BMI': '16.41', '姓名': '林思賢', '狀態': '體重過輕', '身高': '178', '體重': '52'},
#  {'BMI': '27.06', '姓名': '周怡啟', '狀態': '輕度肥胖', '身高': '155', '體重': '65'},
#  {'BMI': '18.61', '姓名': '張牧聿', '狀態': '體重正常', '身高': '184', '體重': '63'},
#  {'BMI': '24.24', '姓名': '林建宏', '狀態': '體重過重', '身高': '165', '體重': '66'},
#  {'BMI': '22.83', '姓名': '賴又琦', '狀態': '體重正常', '身高': '158', '體重': '57'},
#  {'BMI': '34.48', '姓名': '陳彥治', '狀態': '中度肥胖', '身高': '157', '體重': '85'},
#  {'BMI': '18.13', '姓名': '賴又琦', '狀態': '體重過輕', '身高': '171', '體重': '53'},
#  {'BMI': '23.18', '姓名': '柯韋成', '狀態': '體重正常', '身高': '175', '體重': '71'},
#  {'BMI': '39.47', '姓名': '盧必妍', '狀態': '重度肥胖', '身高': '151', '體重': '90'},
#  {'BMI': '31.59', '姓名': '楊韻如', '狀態': '中度肥胖', '身高': '165', '體重': '86'},
#  {'BMI': '28.98', '姓名': '張明惟', '狀態': '輕度肥胖', '身高': '163', '體重': '77'},
#  {'BMI': '21.36', '姓名': '黃詩妃', '狀態': '體重正常', '身高': '159', '體重': '54'},
#  {'BMI': '20.16', '姓名': '藍哲嘉', '狀態': '體重正常', '身高': '189', '體重': '72'},
#  {'BMI': '26.3', '姓名': '王怡珊', '狀態': '體重過重', '身高': '170', '體重': '76'},
#  {'BMI': '33.78', '姓名': '蕭淑華', '狀態': '中度肥胖', '身高': '150', '體重': '76'},
#  {'BMI': '21.62', '姓名': '吳晴洋', '狀態': '體重正常', '身高': '185', '體重': '74'},
#  {'BMI': '19.13', '姓名': '林思賢', '狀態': '體重正常', '身高': '168', '體重': '54'},
#  {'BMI': '26.37', '姓名': '林冠蕙', '狀態': '體重過重', '身高': '157', '體重': '65'},
#  {'BMI': '29.55', '姓名': '陳向愛', '狀態': '輕度肥胖', '身高': '155', '體重': '71'},
#  {'BMI': '31.2', '姓名': '元延辛', '狀態': '中度肥胖', '身高': '154', '體重': '74'}]
