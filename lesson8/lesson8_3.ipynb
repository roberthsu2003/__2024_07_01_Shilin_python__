# %%
def menu(wine, entree='牛排', dessert='蛋糕'):
    print(f"酒類:{wine}")
    print(f"主餐:{entree}")
    print(f"點心:{dessert}")

# %%
menu('白酒')
print("========")
menu('白酒',dessert='冰淇淋')
print("========")
menu('白酒',dessert='冰淇淋',entree='雞排')
# Out:
# 酒類:白酒
# 主餐:牛排
# 點心:蛋糕
# ...
# 酒類:白酒
# 主餐:牛排
# 點心:冰淇淋
# ...
# 酒類:白酒
# 主餐:雞排
# 點心:冰淇淋
