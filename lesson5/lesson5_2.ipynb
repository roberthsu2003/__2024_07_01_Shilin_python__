# %%
score = int(input('請輸入學生分數(最高300分):'))
if score < 0:        
    print("輸入數值要大於等於0")

if score > 300:
    print("輸入數值要小於等於300")

if score >= 0:
    if score <= 300:
        print("在0~300內")
# Out:
# 輸入數值要小於等於300

# %%
score = int(input('請輸入學生分數(最高300分):'))
if score < 0:        
    print("輸入數值要大於等於0")

if score > 300:
    print("輸入數值要小於等於300")

if score >= 0 and score <= 300:
   print("在0~300內")
# Out:
# 在0~300內
