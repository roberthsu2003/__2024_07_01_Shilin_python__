# %%
import random
import numpy as np
import pandas as pd

with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)

with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df

# %%
sum_series = student_df.sum(axis=1)

# %%
from pandas import Series,DataFrame
def fun1(s:Series):
    #傳出不及格的數量
    return s[s < 60].count()

student_df['不及格的科目數'] = student_df.apply(fun1,axis=1)
student_df

# %%
def fun2(s:Series):
    #傳出不及格的數量
    s = s[:5]
    index = s[s<60].index
    return index.values

student_df['不及格的科目'] = student_df.apply(fun2,axis=1)
student_df
# Out:
#      國文  英文   數學   地理   歷史  不及格的科目數            不及格的科目
# 林淑安  61  73   90   63   70        1                []
# 賴昌韻  98  71   56   90   64        2              [數學]
# 王筱婷  87  80   83   95   89        1                []
# 劉旭士  81  68   98   54  100        2              [地理]
# 游治旺  97  60   57   99   99        2              [數學]
# 方筠紹  50  69   62   76   63        2              [國文]
# 蘇婷婷  65  76  100   61   92        1                []
# 錢佩豪  97  68   98   63   99        1                []
# 王泓泰  97  71   82   76   64        1                []
# 楊韋廷  61  55   51   69   88        3          [英文, 數學]
# 余月修  98  81   93   93   63        1                []
# 楊又源  93  59   55   77   64        3          [英文, 數學]
# 黃旻林  72  51   63   83   90        2              [英文]
# 王良斌  98  51   90   51   76        3          [英文, 地理]
# 盧冠發  58  81   51   90   74        3          [國文, 數學]
# 李慈啟  85  62   75   65   87        1                []
# 陳姵彬  92  52   92   94   53        3          [英文, 歷史]
# 張慧君  59  61   57   74   72        3          [國文, 數學]
# 藍哲嘉  91  58   98   55   78        3          [英文, 地理]
# 李立偉  71  66   91   80   98        1                []
# 李佳彥  58  63   50   53   69        4      [國文, 數學, 地理]
# 張明惟  91  92   54   62   56        3          [數學, 歷史]
# 陳奇瑄  62  80   64   95   68        1                []
# 王怡君  95  68   84   62   99        1                []
# 蕭怡伶  52  54  100   78   54        4      [國文, 英文, 歷史]
# 唐翊修  63  61   94   63   74        1                []
# 張彥博  94  90   50   63   98        2              [數學]
# 陳怡珊  69  56   98   50   54        4      [英文, 地理, 歷史]
# 潘英迪  66  52   76   68   79        2              [英文]
# 鄭淑珍  69  52   57   53   66        4      [英文, 數學, 地理]
# 杜明延  96  50   70   66   79        2              [英文]
# 周怡啟  86  88   70   84   88        1                []
# 吳晴洋  77  54   51   84   69        3          [英文, 數學]
# 黃翔杰  59  97   63   54   52        4      [國文, 地理, 歷史]
# 崔孝憲  96  61   96   58   53        3          [地理, 歷史]
# 陳怡容  52  81   77   66   77        2              [國文]
# 張軒宸  50  57   99   50   50        5  [國文, 英文, 地理, 歷史]
# 方雅慧  62  58   76   98   97        2              [英文]
# 唐雪豪  90  93   56  100   78        2              [數學]
# 王梅劭  58  69   95   96   63        2              [國文]
# 劉旭士  66  64   80   53   98        2              [地理]
# 張莉雯  67  94   96   62   62        1                []
# 陳樂紫  96  79   62   78   94        1                []
# 林佳光  85  74   57   57   97        3          [數學, 地理]
# 游治旺  79  84   68   75   98        1                []
# 楊健麟  81  79   65   90   58        2              [歷史]
# 林士凱  54  99   72   52   62        3          [國文, 地理]
# 林玉佩  77  71   57   55   81        3          [數學, 地理]
# 王怡珊  56  78   71   70   94        2              [國文]
# 潘英迪  97  76   64   63   77        1                []
